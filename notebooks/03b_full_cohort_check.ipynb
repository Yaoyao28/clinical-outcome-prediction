# %%
import pandas as pd
df = pd.read_csv("../data/raw/full/modeling_cohort_full.csv")
print(df.shape)
print(df["hospital_expire_flag"].mean())
print(df["subject_id"].nunique())
df.isna().mean().sort_values(ascending=False).head(15)
